# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math

import torch
import torch.nn as nn
from torch.optim import RMSprop

from torch.utils.data import DataLoader, TensorDataset

# %%
data = pd.read_csv('../data/jhu-covid-cases.csv')
data = data[data.Province_State == 'West Virginia']
data = data[data.columns[11:]]
print(data.columns[:5])

death = pd.read_csv('../data/jhu-covid-deaths.csv')
death = death[death.Province_State == 'West Virginia']
death = death[death.columns[12:]]
print(death.columns[:5]) # make sure the dates match

data = np.array(data.sum(axis = 0)) #.reshape(-1, 1)
data = np.convolve(data, np.ones(7) / 7, 'valid')
data = torch.tensor(data)
Itilde = torch.log(1 + data[20:] - data[:-20]).reshape(1, -1)

death = torch.tensor(death.sum(axis = 0))
Dt = torch.tensor(np.convolve(death, np.ones(7) / 7, 'valid'))
Dtilde = torch.log(1 + Dt[:-20]).reshape(1, -1)

N = 1_775_000 
Ntilde = math.log(1 + N)

Stilde = torch.log(N - torch.exp(Itilde) - torch.exp(Dtilde))

first_index = torch.arange(1117)[Itilde[0,:] > 4.6][0].item() # first index above 100 cases 

Stilde = Stilde[:,first_index:].T
Itilde = Itilde[:,first_index:].T
Dtilde = Dtilde[:,first_index:].T

Y = torch.hstack((Stilde, Itilde, Dtilde))
T = torch.arange(1073).reshape(-1, 1) * 1.

print(T.shape, Y.shape) # make sure shapes match
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20'], dtype='object')
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20'], dtype='object')
# torch.Size([1073, 1]) torch.Size([1073, 3])

# %%
class Greek(nn.Module): # 1 to 1 (time to positive value)
    def __init__(self):
        super().__init__()
        self.lin1 = nn.Linear(1, 16)
        self.lin2 = nn.Linear(16, 16)
        self.lin3 = nn.Linear(16, 16)
        self.lin4 = nn.Linear(16, 1)

        self.act = nn.GELU()

        #self.param = nn.Parameter(torch.randn(1078, 1))

    #"""
    def forward(self, x):
        x = x / 1000 # ich hab kein lust das zu preprocessieren :P
        x = self.lin1(x)
        x = self.act(x)
        x = self.lin2(x)
        x = self.act(x)
        x = self.lin3(x)
        x = self.act(x)
        x = self.lin4(x)
        return 1 + torch.sin(x)

    #"""
    #def forward(self, t):
    #    print(t)
    #    return torch.exp(self.param[t])

class Curves(nn.Module): # put all 3 in 1
    def __init__(self, T = 1078):
        super().__init__()
        self.lin1 = nn.Linear(1, 48)
        self.lin2 = nn.Linear(48, 48)
        self.lin3 = nn.Linear(48, 48)
        self.lin4 = nn.Linear(48, 48)
        self.lin5 = nn.Linear(48, 3)

        self.act = nn.GELU()

        self.gamma = Greek()
        self.beta = Greek()
        self.mu = Greek()

    def forward(self, x): # takes time and produces S, I, T estimates
        x = x / 1000 # again to avoid preprocessing
        x = self.lin1(x)
        x = self.act(x)
        x = self.lin2(x)
        x = self.act(x)
        x = self.lin3(x)
        x = self.act(x)
        x = self.lin4(x)
        x = self.act(x)
        x = self.lin5(x)

        return Ntilde * x # so the model only has to predict something smaller

    def get_derivative(self, t):
        t = t / 1000
        t.requires_grad = True
        
        x = self.forward(t)

        grad_s = torch.autograd.grad(x[:,0].sum(), t, create_graph=True)[0]
        grad_i = torch.autograd.grad(x[:,1].sum(), t, create_graph=True)[0]
        grad_d = torch.autograd.grad(x[:,2].sum(), t, create_graph=True)[0]
        
        return grad_s, grad_i, grad_d

# %%
NN = Curves()
optimizer = RMSprop(NN.parameters(), lr = 1e-3)

EPOCHS = 500
dataset = DataLoader(TensorDataset(T, Y), batch_size = 25, shuffle = True)
losses = []

for i in range(EPOCHS):

    total_loss = 0.

    for t, y in dataset:
        optimizer.zero_grad()
        
        y_hat = NN(t)

        ## assemble losses
        ### distance from the model output to the actual curves
        curve_loss = torch.sum((y - y_hat)**2)
        
        ### pde losses
        dsdt, didt, dddt = NN.get_derivative(t)

        mu_t = NN.mu(t)
        beta_t = NN.beta(t)
        gamma_t = NN.gamma(t)

        dsdt_hat = gamma_t * torch.exp(y_hat[:,2] - y_hat[:,0]).reshape(-1, 1) - beta_t * torch.exp(y_hat[:,1] - Ntilde).reshape(-1, 1)
        dddt_hat = mu_t * torch.exp(y_hat[:,1] - y_hat[:,2]).reshape(-1, 1)
        didt_hat = beta_t * torch.exp(y_hat[:,0] - Ntilde).reshape(-1, 1) - \
                    mu_t * torch.exp(y_hat[:,2] - y_hat[:,1]).reshape(-1, 1) - gamma_t

        dsdt_loss = torch.sum((dsdt - dsdt_hat)**2)
        dddt_loss = torch.sum((dddt - dddt_hat)**2)
        didt_loss = torch.sum((didt - didt_hat)**2)

        pde_loss = dddt_loss + dsdt_loss + didt_loss

        ### boundary loss
        pde_bound = torch.sum((dsdt + didt + dddt)**2)
        curve_bound = 0. #torch.sum((Ntilde - torch.log(torch.exp(y_hat).sum(axis = 1)))**2)

        boundary_loss = pde_bound + curve_bound
        
        ### total loss assemble
        l = 100 * pde_loss + curve_loss + (10 * boundary_loss)
        
        l.backward()
        optimizer.step()

        total_loss += l.item() #.detach()

    losses.append(total_loss)

    if i % 9 == 0:
        print('=== Epoch', i, '| PDE:', round(100 * pde_loss.item(), 4), '| Curve:', round(curve_loss.item(), 4), '| Boundary:', round(10 * boundary_loss.item(), 4),  '===')
# Out:
# === Epoch 0 | PDE: 1752.4948 | Curve: 7753.3941 | Boundary: 0.0 ===
# === Epoch 9 | PDE: 7.3578 | Curve: 73.1877 | Boundary: 0.0207 ===
# === Epoch 18 | PDE: 0.1853 | Curve: 38.8524 | Boundary: 0.0902 ===
# === Epoch 27 | PDE: 0.4927 | Curve: 29.6007 | Boundary: 0.1816 ===
# === Epoch 36 | PDE: 0.9073 | Curve: 24.5376 | Boundary: 0.3769 ===
# === Epoch 45 | PDE: 0.3544 | Curve: 21.795 | Boundary: 0.4704 ===
# === Epoch 54 | PDE: 1.0877 | Curve: 26.4492 | Boundary: 0.4612 ===
# === Epoch 63 | PDE: 0.4523 | Curve: 19.8504 | Boundary: 0.4391 ===
# === Epoch 72 | PDE: 0.6673 | Curve: 27.9465 | Boundary: 0.4223 ===
# === Epoch 81 | PDE: 0.4063 | Curve: 20.5337 | Boundary: 0.2716 ===
# === Epoch 90 | PDE: 0.1058 | Curve: 18.5244 | Boundary: 0.2168 ===
# === Epoch 99 | PDE: 0.4992 | Curve: 15.8907 | Boundary: 0.1522 ===
# === Epoch 108 | PDE: 0.3846 | Curve: 15.3336 | Boundary: 0.0975 ===
# === Epoch 117 | PDE: 0.1317 | Curve: 20.426 | Boundary: 0.1088 ===
# === Epoch 126 | PDE: 0.6497 | Curve: 17.6189 | Boundary: 0.0979 ===
# === Epoch 135 | PDE: 0.5443 | Curve: 17.2063 | Boundary: 0.0857 ===
# === Epoch 144 | PDE: 0.4575 | Curve: 20.4849 | Boundary: 0.0532 ===
# === Epoch 153 | PDE: 0.4113 | Curve: 16.5001 | Boundary: 0.0908 ===
# === Epoch 162 | PDE: 0.443 | Curve: 15.0157 | Boundary: 0.1996 ===
# === Epoch 171 | PDE: 0.6108 | Curve: 8.3665 | Boundary: 0.0738 ===
# === Epoch 180 | PDE: 0.5599 | Curve: 15.1031 | Boundary: 0.1897 ===
# === Epoch 189 | PDE: 0.4251 | Curve: 10.6568 | Boundary: 0.0363 ===
# === Epoch 198 | PDE: 0.2419 | Curve: 9.3746 | Boundary: 0.0067 ===
# === Epoch 207 | PDE: 0.0977 | Curve: 9.4392 | Boundary: 0.0003 ===
# === Epoch 216 | PDE: 0.0294 | Curve: 11.7849 | Boundary: 0.0129 ===
# === Epoch 225 | PDE: 0.2815 | Curve: 8.7064 | Boundary: 0.0254 ===
# === Epoch 234 | PDE: 0.0881 | Curve: 7.7416 | Boundary: 0.0045 ===
# === Epoch 243 | PDE: 0.3452 | Curve: 7.9145 | Boundary: 0.0104 ===
# === Epoch 252 | PDE: 0.1389 | Curve: 5.3809 | Boundary: 0.0298 ===
# === Epoch 261 | PDE: 0.0046 | Curve: 8.3403 | Boundary: 0.0006 ===
# === Epoch 270 | PDE: 0.0513 | Curve: 5.2288 | Boundary: 0.008 ===
# === Epoch 279 | PDE: 0.0158 | Curve: 7.4248 | Boundary: 0.0011 ===
# === Epoch 288 | PDE: 0.0392 | Curve: 3.484 | Boundary: 0.065 ===
# === Epoch 297 | PDE: 0.0315 | Curve: 3.0408 | Boundary: 0.0308 ===
# === Epoch 306 | PDE: 0.018 | Curve: 3.0332 | Boundary: 0.0017 ===
# === Epoch 315 | PDE: 0.0226 | Curve: 3.3935 | Boundary: 0.0096 ===
# === Epoch 324 | PDE: 0.0159 | Curve: 4.5586 | Boundary: 0.0009 ===
# === Epoch 333 | PDE: 0.3764 | Curve: 40.3668 | Boundary: 0.0003 ===
# === Epoch 342 | PDE: 0.0582 | Curve: 3.8583 | Boundary: 0.0049 ===
# === Epoch 351 | PDE: 0.133 | Curve: 5.113 | Boundary: 0.0025 ===
# === Epoch 360 | PDE: 0.1807 | Curve: 15.2599 | Boundary: 0.0984 ===
# === Epoch 369 | PDE: 0.0439 | Curve: 2.7143 | Boundary: 0.0099 ===
# === Epoch 378 | PDE: 0.1591 | Curve: 4.6251 | Boundary: 0.0065 ===
# === Epoch 387 | PDE: 0.0135 | Curve: 8.9345 | Boundary: 0.0125 ===
# === Epoch 396 | PDE: 0.0784 | Curve: 1.7554 | Boundary: 0.0019 ===
# === Epoch 405 | PDE: 0.0234 | Curve: 5.1364 | Boundary: 0.0089 ===
# === Epoch 414 | PDE: 0.6076 | Curve: 1.5266 | Boundary: 0.011 ===
# === Epoch 423 | PDE: 0.0137 | Curve: 3.6011 | Boundary: 0.0155 ===
# === Epoch 432 | PDE: 0.0152 | Curve: 4.8021 | Boundary: 0.0009 ===
# === Epoch 441 | PDE: 0.0441 | Curve: 2.4857 | Boundary: 0.0002 ===
# === Epoch 450 | PDE: 0.4123 | Curve: 47.0712 | Boundary: 0.2013 ===
# === Epoch 459 | PDE: 0.0036 | Curve: 2.9787 | Boundary: 0.0005 ===
# === Epoch 468 | PDE: 0.0231 | Curve: 2.2626 | Boundary: 0.0004 ===
# === Epoch 477 | PDE: 0.0321 | Curve: 4.4529 | Boundary: 0.0053 ===
# === Epoch 486 | PDE: 0.0426 | Curve: 2.6093 | Boundary: 0.0004 ===
# === Epoch 495 | PDE: 0.0374 | Curve: 3.8831 | Boundary: 0.0055 ===

# %%
plt.plot(losses[20:])

# %%
with torch.no_grad():
    plt.plot(NN(T)[:,2])
    plt.plot(Dtilde)

# %%
with torch.no_grad():
    plt.plot(NN(T)[:,1])
    plt.plot(Itilde)

# %%
with torch.no_grad():
    plt.plot(NN.beta(T)[:,0])

# %%
with torch.no_grad():
    plt.plot(NN.gamma(T)[:,0])

# %%
with torch.no_grad():
    plt.plot(NN.mu(T)[:,0])
